# %% [markdown]
# ## 大作业代码思路参考
#
# - 编程语言：Python
#
# - 时间要求：**2021/7/16 **- **2021/7/29**
#
# - 前期准备：Python基础（类，函数），顺序栈、链栈、顺序队列、链式队列、双端队列等基本原理；
#
# - 上传要求：本章共有**7个任务**，需要分成**7个ipynb格式**的文档来写！
#
# - 内容要求：主要看下面具体的任务要求，**前5个任务**只要展示函数运行结果就可；最后**两个任务**（**栈的应用**和**队列的应用**）会明确给出具体的**测试案例**以及**运行结果**，小伙伴们需要运行出来给定的结果，才算完成！；

# %% [markdown]
# ### 任务一：顺序栈的表示和实现（难度：★）
#
# 　　关于顺序栈，我认为呢，唯一的难点就是关于**栈的原理**，小伙伴们一定理解好**出栈入栈**，其他的代码基本跟顺序表逻辑差不多。
#
# 　　栈的原理用简洁的话就是：**先进后出**，**后进先出**；
#
# 　　参考思路：假设我们创建一个**空栈**对象（对于顺序栈来说，就以**列表**表示即可），**进栈**就是**往列表后面依次添加元素**（append函数），**出栈**就是**删除列表中最后一个元素**（pop函数），**返回栈顶元素**通过pop函数的返回值就可获取到，**返回栈的长度**通过len函数，**清空栈**直接让列表等于空列表；

# %% [markdown]
# ### 任务二：链栈的表示和实现（难度：★★）
#
# 　　参考思路：跟线性表中的链表部分差不多思路，先创建两个类，一个表示节点类（包含data和next指针），一个表示栈类，栈初始化时有三部分（栈顶、栈底以及栈的长度），进栈的话就是采用链表的尾插法，出栈的话就是删除尾节点，其他函数跟链表差不多了；

# %% [markdown]
# ### 任务三：队列的顺序表示和实现（难度：★）
#
# 　【注】：关于顺序队列，只要能够区分跟栈的不同之处就可以了，代码大部分都是很相似的，只有再入队和出队有所不同罢了；栈是**先进后出，后进先出**，队列是**先进先出，后进后出**！

# %% [markdown]
# ### 任务四：队列的链式表示和实现（难度：★★）
#
# 　队列的链式实现参考栈的就可！都是跟线性表中的链表代码很相似；

# %% [markdown]
# ### 任务五：双端队列的顺序表示和实现（难度：★★）
#
# **实现基本功能**：（包括但不限于，可以根据自己能力继续扩展）
#
# 　　（1）**同顺序队列和链式队列一样**（8个函数均要实现，不同之处在于，见下）
#
# 　　（2）**队头入队** : 添加元素到队头
#
# 　　（3）**队尾入队** : 添加元素到队尾
#
# 　　（4）**队头出队** : 删除队头元素
#
# 　　（5）**队尾出队** : 删除队尾元素
#
# 　【注】：**双端队列**类似于**双向链表**的思路，这里小伙伴可以参考双向链表的实现，当然为了降低一定难度，这里只要实现双端队列的顺序表示就可以了，也就是**列表**。**其中队头入队即为再列表第一个索引位置添加元素，队尾入队即为列表最后添加元素，队头出队队尾出队同理；**

# %% [markdown]
# ### 任务六：栈的应用（难度：★★）

# %% [markdown]
# #### 应用1：括号匹配问题
#
# 　　检验算法借助一个栈，每当读入一个左括号，则直接入栈，等待相匹配的同类右括号；每当读入一个右括号，若与当前栈顶的左括号类型相同，则二者匹配，将栈顶的左括号出栈，直到表达式扫描完毕。
#
# 　　在处理过程中，还要考虑括号不匹配出错的情况。例如，当出现 (()[]) 这种情况时，由于前面入栈的左括号均已知和后面出现的右括号相匹配，栈已空，因此最后扫描的右括号不能得到匹配；出现 [([]) 这种错误，当表达式扫描结束时，栈中还有一个左括号没有匹配；出现 (()] 这种错误显然是栈顶的左括号和最后的右括号不匹配。
#
# **测试案例**：（小伙伴们需要拿以下三个案例测试自己写的代码哈！）
# 　　案例1：{{([][])}()}
# 　　案例2：[[{{(())}}]]
# 　　案例3：[[(()(()))])]{}
#
# **运行结果**：
#
# ![Image Name](https://cdn.kesci.com/upload/image/qw9ntwcxgw.png?imageView2/0/w/320/h/320)

# %% [markdown]
# - 参考伪代码

# %%
# 匹配函数，最终返回True和False
def matching(strings):
    stack = Stack() # 创建一个空栈，存储左括号
    flag = 1 # 标记匹配结果以控制循环及返回结果
    opens = '{[(' 
    closes = '}])' # 必须和opens里的括号相匹配
    for string in strings:
        # 如果string为左括号时，入栈
        # 如果string为右括号时，将最后一个元素出栈，并判断出栈的元素索引在opens的位置和closes右括号位置是否匹配，如果不匹配，则匹配错误！
        # 如果以上都不是，则直接返回False
    # 根据最后的元素是否为空，判断是否匹配正确

# 判断返回的是True还是False
def check(strings):
    if matching(strings):
        print("%s 匹配正确!" % strings)
    else:
        print("%s 匹配错误！" % strings)

# %% [markdown]
# #### 应用2：十进制转二进制
#
# 　　当将一个十进制整数M转换为二进制数时，在计算过程中，把M与2求余得到的二进制数的各位依次进栈，计算完毕后将栈中的二进制数依次出栈输出，输出结果就是待求得的二进制数。
#
# **测试案例**：
# 　　[200, 254, 153, 29, 108, 631, 892]
#
# **运行结果**：
#
# ![Image Name](https://cdn.kesci.com/upload/image/qw9o9hwjth.png?imageView2/0/w/320/h/320)
#
# 　【注】：小伙伴们需要完成以上测试哈，而且必须使用哦，主要为了方便作业统一！

# %% [markdown]
# - 参考伪代码

# %%
# 利用栈实现十进制转二进制
def divideBy2(number):
    stack = Stack() #创建一个空栈，存储二进制01数
    
    while number > 0:
        # number对2求模，得到0或者1
        # 然后将0和1入栈
        # 对number整除2后求商，并将得到的值覆盖number
    
    # 定义一个存储二进制数的空字符串
    # 通过判断栈是否为空，依次循环遍历
        # 调用Pop删除栈顶元素并返回值，将值合并到空字符串中
    #最后直接返回拼接后的字符串即为转换后的二进制数

# %% [markdown]
# #### 应用3：十进制转N进制（应用2的拓展）
#
# 　　当将一个十进制整数M转换为N进制数时，在计算过程中，把M与N求余得到的N进制数的各位依次进栈，计算完毕后将栈中的N进制数依次出栈输出，输出结果就是待求得的N进制数。
#
# **测试案例**：
# 　　测试数：[200, 254, 153, 29, 108, 631, 892]
# 　　进制：[4, 8, 16]
#
# 　　自由搭配即可，这里我主要使用了**random.choice()**来对测试数要转换的进制随机取数，测试代码如下所示，仅供参考；
#
# ![Image Name](https://cdn.kesci.com/upload/image/qw9oj3vnme.png?imageView2/0/w/640/h/640)
#
# **运行结果**：
#
# ![Image Name](https://cdn.kesci.com/upload/image/qw9oh3umsz.png?imageView2/0/w/320/h/320)
#
# 　【注】：小伙伴们需要完成以上测试哈，而且必须使用测试案例哦！

# %% [markdown]
# ### 任务7：队列的应用（难度：★★）

# %% [markdown]
# #### 应用1：回文词检验
#
# 　　回文词检查是数据结构中的常见任务，这一任务可以应用双端队列直观有效地完成。将待检查的字符串按顺序载入队列，首尾两侧弹出并比较，出现不一致时则判断为不是回文数。当队列为空或只剩一个元素是可以判断为回文数。
#
# **测试案例**：
# 　　案例1：abcgcba
# 　　案例2：refer
# 　　案例3：reference
#
# **运行结果**：
#
# ![Image Name](https://cdn.kesci.com/upload/image/qw9p0d2ijt.png?imageView2/0/w/320/h/320)
#
# 　【注】：小伙伴们需要完成以上测试哈，而且必须使用测试案例哦！

# %% [markdown]
# - 参考伪代码

# %%
# 回文词判定 -- 双端队列实现
def palchecker(aString): # 定义回文词判断函数，需要一个参数字符串 aString
    # 初始化一个双端队列 queue
    # 通过循环，依次双端队列尾端加入所有aString的元素
        
    # 通过判断队列是否为空，进行遍历
        # 依次取出队头和队尾元素，并进行比较是否一样，只要有一次不一样，就直接返回False，说明不是回文词
        # 如果遍历的时候所有取出的队头和队尾都一样，那么就说明是回文词
